# %%
import pandas as pd

# %%
target = pd.read_excel('/Users/anjonghyeon/Desktop/KU/민족문화연구원 사전실/openpro/kordic/asset/한한중 이전말_지연검토.xlsx', engine='openpyxl')
target
# Out:
#        표제어번호      표제어  어깨말         원어  의항2      품사  \
# 0     3672.0      가출옥  NaN        假出獄  NaN      명사
# 1     5662.0       간질  NaN         癎疾  NaN      명사
# 2    11403.0      개찰구  NaN        改札口  NaN      명사
# 3    62454.0     내분비선  NaN        NaN  NaN      명사
# 4    62541.0       내상  NaN         內傷  NaN      명사
# 5    66059.0     노이로제  NaN  독.Neurose  NaN      명사
# 6    72746.0      다한증  NaN        多汗症  NaN      명사
# 7    99623.0      림프선  NaN        NaN  NaN      명사
# 8   112813.0     몽고반점  NaN        NaN  NaN      명사
# 9   116502.0   무형 문화재  NaN      無形文化財  NaN    구표제어
# 10  117981.0      문화재  NaN        文化財  NaN      명사
# 11  211271.0      안경점  NaN        NaN  NaN      명사
# 12  213095.0   알코올 중독  NaN        NaN  NaN    구표제어
# 13  213096.0  알코올 중독자  NaN        NaN  NaN    구표제어
# 14  215755.0      액취증  NaN        NaN  NaN      명사
# 15  219115.0    양호 교사  NaN        NaN  NaN    구표제어
# 16  232436.0      예배당  NaN        禮拜堂  NaN      명사
# ...

# %%
with open('../result/aa.txt', 'w') as file:
    LEN = len(target)
    for i in range(LEN):
        file.write(str(target.loc[i, '표제어번호']) + ', ')
